# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiakash1508/wordcounter/blob/main/wordcounter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-7458d37e-2cea-4249-ac8d-820504257345" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7458d37e-2cea-4249-ac8d-820504257345">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
f=open('/content/tcsaptitude.txt','r')
c=[]
for x in f:
  #print(x)
  c.append(x.split(' '))
print(c)
# Out:
# [['1:', 'There', 'is', 'a', 'toy', 'train', 'that', 'can', 'make', '10', 'musical', 'sounds.', 'It', 'makes', '2', 'musical', 'sounds', 'after', 'being\n'], ['defective.', 'What', 'is', 'the', 'probability', 'that', 'same', 'musical', 'sound', 'would', 'be', 'produced', '5', 'times\n'], ['consecutively?', '(1', 'of', ')?\n'], ['\n'], ['Answer:', '1/2', '*', '1/2', '*', '1/2', '*', '1/2', '*', '1/2', '=', '1/32\n'], ['\n'], ['32', 'will', 'be', 'the', 'answer.\n'], ['\n'], ['2:', 'Peter', 'and', 'Paul', 'are', 'two', 'friends.', 'The', 'sum', 'of', 'their', 'ages', 'is', '35', 'years.', 'Peter', 'is', 'twice', 'as', 'old', 'as', 'Paul\n'], ['was', 'when', 'Peter', 'was', 'as', 'old', 'as', 'Paul', 'is', 'now.', 'What', 'is', 'the', 'present', 'age', 'of', 'Peter?\n'], ['\n'], ['Answer:', '20', 'years.\n'], ['\n'], ['3:', 'The', 'ages', 'of', 'two', 'friends', 'is', 'in', 'the', 'ratio', '6:5.', 'The', 'sum', 'of', 'their', 'ages', 'is', '66.After', 'how', 'many', 'years\n'], ['will', 
# ...

# %%
word=0
for i in range(len(c)):
  word+=1
print(word)
# Out:
# 2718
